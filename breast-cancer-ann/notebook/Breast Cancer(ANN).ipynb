# %%
from sklearn.datasets import load_breast_cancer
import tensorflow as tf
import numpy as np

# %%
data = load_breast_cancer()
x = data.data
y = data.target

# %%
x.shape
# Out:
# (569, 30)

# %%
x[:2]
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01, 2.776e-01,
#         3.001e-01, 1.471e-01, 2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01,
#         8.589e+00, 1.534e+02, 6.399e-03, 4.904e-02, 5.373e-02, 1.587e-02,
#         3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01, 1.846e+02, 2.019e+03,
#         1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, 1.326e+03, 8.474e-02, 7.864e-02,
#         8.690e-02, 7.017e-02, 1.812e-01, 5.667e-02, 5.435e-01, 7.339e-01,
#         3.398e+00, 7.408e+01, 5.225e-03, 1.308e-02, 1.860e-02, 1.340e-02,
#         1.389e-02, 3.532e-03, 2.499e+01, 2.341e+01, 1.588e+02, 1.956e+03,
#         1.238e-01, 1.866e-01, 2.416e-01, 1.860e-01, 2.750e-01, 8.902e-02]])

# %%
from keras.utils import to_categorical
y = to_categorical(y, num_classes=2)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.25, random_state=42)

# %%
x_train.shape
# Out:
# (426, 30)

# %%
x_test.shape
# Out:
# (143, 30)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()

model.add(Dense(units=32, activation='relu', input_shape=(x.shape[1],)))
model.add(Dropout(.30))

model.add(Dense(units=64, activation='relu'))
model.add(Dropout(.30))

model.add(Dense(units=128, activation='relu'))
model.add(Dropout(.30))

model.add(Dense(units=2, activation='sigmoid'))

# %%
from tensorflow.keras.metrics import Precision, Recall

model.compile(loss=tf.keras.losses.binary_crossentropy,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy', Precision(), Recall()])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 32)             │           992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,682 (45.63 KB)
#  Trainable params: 11,682 (45.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train, batch_size=16, epochs=25, validation_data=(x_test, y_test))
# Out:
# Epoch 1/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9870 - loss: 0.0344 - precision_1: 0.9885 - recall_1: 0.9863 - val_accuracy: 0.9720 - val_loss: 0.0858 - val_precision_1: 0.9720 - val_recall_1: 0.9720
# Epoch 2/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9797 - loss: 0.0556 - precision_1: 0.9797 - recall_1: 0.9797 - val_accuracy: 0.9790 - val_loss: 0.0658 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 3/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9805 - loss: 0.0606 - precision_1: 0.9805 - recall_1: 0.9805 - val_accuracy: 0.9790 - val_loss: 0.0717 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 4/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9827 - loss: 0.0480 - precision_1: 0.9827 - recall_1: 0.9827 - val_accuracy: 0.9790 - val_loss: 0.0769 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 5/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9855 - loss: 0.0279 - precision_1: 0.9855 - recall_1: 0.9855 - val_accuracy: 0.9790 - val_loss: 0.0832 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 6/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9923 - loss: 0.0318 - precision_1: 0.9923 - recall_1: 0.9923 - val_accuracy: 0.9790 - val_loss: 0.0834 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 7/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9905 - loss: 0.0459 - precision_1: 0.9905 - recall_1: 0.9869 - val_accuracy: 0.9790 - val_loss: 0.0811 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 8/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9894 - loss: 0.0473 - precision_1: 0.9894 - recall_1: 0.9883 - val_accuracy: 0.9790 - val_loss: 0.0885 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 9/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - loss: 0.0177 - precision_1: 0.9955 - recall_1: 0.9955 - val_accuracy: 0.9790 - val_loss: 0.0821 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 10/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9761 - loss: 0.0410 - precision_1: 0.9762 - recall_1: 0.9778 - val_accuracy: 0.9790 - val_loss: 0.0878 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 11/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9953 - loss: 0.0221 - precision_1: 0.9953 - recall_1: 0.9953 - val_accuracy: 0.9790 - val_loss: 0.0956 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 12/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9850 - loss: 0.0268 - precision_1: 0.9799 - recall_1: 0.9877 - val_accuracy: 0.9720 - val_loss: 0.1038 - val_precision_1: 0.9720 - val_recall_1: 0.9720
# Epoch 13/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9927 - loss: 0.0327 - precision_1: 0.9927 - recall_1: 0.9846 - val_accuracy: 0.9790 - val_loss: 0.1013 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 14/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9883 - loss: 0.0507 - precision_1: 0.9883 - recall_1: 0.9883 - val_accuracy: 0.9790 - val_loss: 0.0862 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 15/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9882 - loss: 0.0325 - precision_1: 0.9870 - recall_1: 0.9882 - val_accuracy: 0.9790 - val_loss: 0.0858 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 16/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9851 - loss: 0.0230 - precision_1: 0.9851 - recall_1: 0.9857 - val_accuracy: 0.9790 - val_loss: 0.0876 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 17/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9904 - loss: 0.0303 - precision_1: 0.9904 - recall_1: 0.9904 - val_accuracy: 0.9860 - val_loss: 0.0846 - val_precision_1: 0.9860 - val_recall_1: 0.9860
# Epoch 18/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9863 - loss: 0.0346 - precision_1: 0.9896 - recall_1: 0.9863 - val_accuracy: 0.9790 - val_loss: 0.0887 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 19/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9917 - loss: 0.0356 - precision_1: 0.9917 - recall_1: 0.9932 - val_accuracy: 0.9720 - val_loss: 0.1267 - val_precision_1: 0.9720 - val_recall_1: 0.9720
# Epoch 20/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9952 - loss: 0.0160 - precision_1: 0.9956 - recall_1: 0.9923 - val_accuracy: 0.9650 - val_loss: 0.1355 - val_precision_1: 0.9718 - val_recall_1: 0.9650
# Epoch 21/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9941 - loss: 0.0252 - precision_1: 0.9968 - recall_1: 0.9941 - val_accuracy: 0.9790 - val_loss: 0.1093 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 22/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9883 - loss: 0.0248 - precision_1: 0.9883 - recall_1: 0.9883 - val_accuracy: 0.9790 - val_loss: 0.1062 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 23/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9929 - loss: 0.0146 - precision_1: 0.9929 - recall_1: 0.9929 - val_accuracy: 0.9790 - val_loss: 0.1198 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 24/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9912 - loss: 0.0150 - precision_1: 0.9988 - recall_1: 0.9912 - val_accuracy: 0.9790 - val_loss: 0.1171 - val_precision_1: 0.9790 - val_recall_1: 0.9790
# Epoch 25/25
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9872 - loss: 0.0307 - precision_1: 0.9872 - recall_1: 0.9872 - val_accuracy: 0.9790 - val_loss: 0.1059 - val_precision_1: 0.9790 - val_recall_1: 0.9790

# %%
from sklearn.metrics import classification_report

y_pred_prob = model.predict(x_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = np.argmax(y_test, axis=1)

print(classification_report(y_true, y_pred, digits=4))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#               precision    recall  f1-score   support
#
#            0     0.9636    0.9815    0.9725        54
#            1     0.9886    0.9775    0.9831        89
#
#     accuracy                         0.9790       143
#    macro avg     0.9761    0.9795    0.9778       143
# weighted avg     0.9792    0.9790    0.9791       143

# %%
model.save('breast_cancer.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
